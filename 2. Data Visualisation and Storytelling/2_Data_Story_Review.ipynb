# %% [markdown]
# # Data Storytelling Self Study
#
# You have some data below about the knockout rounds from the UEFA Euro 2020 knockout phase.
#
# This notebook is for you to come up with visualisations to plot this information and add more and more elements to tell a data story.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
euros = pd.read_excel('data/excel-data.xlsx', sheet_name='Euros', header=3)
euros
# Out:
#    Group          Country  Goals
# 0      C          Austria      4
# 1      B          Belgium      7
# 2      D          Croatia      4
# 3      D   Czech Republic      3
# 4      B          Denmark      5
# 5      D          England      2
# 6      B          Finland      1
# 7      F           France      4
# 8      F          Germany      6
# 9      F          Hungary      3
# 10     A            Italy      7
# 11     C      Netherlands      8
# 12     C  North Macedonia      2
# 13     E           Poland      4
# 14     F         Portugal      7
# 15     B           Russia      2
# 16     D         Scotland      1
# 17     E         Slovakia      2
# 18     E            Spain      6
# 19     E           Sweden      4
# 20     A      Switzerland      4
# 21     A           Turkey      1
# 22     C          Ukraine      4
# 23     A            Wales      3

# %% [markdown]
# # Exercise 2: Choosing the right chart
#
# There are two parts to this exercise:
#
# ## A. Recreate the following chart
#
# ![image-3.png](attachment:image-3.png)

# %%
# Out:
# <AxesSubplot:title={'center':'Goals in the group stage (Euros 2020)'}, xlabel='Country'>

# %% [markdown]
# ## B. Make two new charts
#
# - One chart should be *better* to present this data
# - One chart should be *worse* to present this data

# %%
# better chart:
# Out:
# <AxesSubplot:title={'center':'Goals in the group stage (Euros 2020)'}, ylabel='Country'>

# %%
# worse chart:
# Out:
# <AxesSubplot:ylabel='Goals'>

# %% [markdown]
# # Exercise 3: Add Characters to the chart
#
# Redesign the graph using the rules below. Make sure your new graph uses each of the rules.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Exercise 4: Add a compelling title
#
# Use the wording "We need..." or "We can..." to add a compelling title that promotes action.
